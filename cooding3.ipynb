# %%
my_tuple = (1, 2, 3)
item_to_add = 4

# TODO: convert tuple to list, add the item, then convert back
temp_list = list(my_tuple)
temp_list.append(item_to_add)
new_tuple = tuple(temp_list)

print(new_tuple)
# Out:
# (1, 2, 3, 4)

# %%
numbers = [5, 10, 15, 20]

total = 0
for num in numbers:
    total += num

print(total)
# Out:
# 50

# %%
numbers = [2, 3, 4]
result = 1
for num in numbers:
    result *= num

print(result)
# Out:
# 24

# %%
numbers = [10, 3, 25, 1, 7]
smallest = numbers[0]
for num in numbers:
    if num < smallest:
        smallest = num

print(smallest)
# Out:
# 1

# %%
numbers = [10, 3, 25, 1, 7]
largest = numbers[0]
for num in numbers:
    if num > largest:
        largest = num

print(largest)
# Out:
# 25

# %%
words = ["hi", "a", "hello", "no", "on","Ashrakat"]

count = 0
for word in words:
    if len(word) >= 2:
        count += 1

print(count)
# Out:
# 5

# %%
original = [1, 2, 3, 4]
cloned = original[:]

print(cloned)
# Out:
# [1, 2, 3, 4]

# %%
my_set = {1, 2, 3, 4, 5}
my_set.discard(3)

print(my_set)
# Out:
# {1, 2, 4, 5}

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}
is_subset = set1.issubset(set2)

print(is_subset)
# Out:
# True
