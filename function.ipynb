# %%
def function(a, b):

   result = a * b

# %%
def multiplication_table(num):
           
    for i in range(1, 11):
            result = num * i
            print(f"{num} * {i} = {result}")

# %%
multiplication_table(9)
# Out:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90
